# %%
# Cargamos librerías
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import xarray as xr
# # import cartopy.crs as ccrs

import os
import glob
# from datetime import datetime, timedelta
# import pandas as pd
# import geopandas as gpd


# import shutil

# import ast
from collections import Counter
# import intake

import json
# from pathlib import Path
# # import mlcast_datasets

# from pyproj import CRS, Transformer
# import tempfile
# import fiona

import random

# import re
# import rasterio
# from rasterio.merge import merge
# from rasterio.transform import Affine
# from rasterio.windows import from_bounds
# from scipy.ndimage import distance_transform_edt
# from rasterio.features import rasterize
# from rasterio.enums import Resampling
# from rasterio.warp import reproject
# from rasterio.transform import from_bounds

# from whitebox import WhiteboxTools

# from shapely.geometry import box

# from scipy.stats import mannwhitneyu
# from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# from PIL import Image

from joblib import Parallel, delayed
import string
import numpy as np


import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch.nn.functional as F

import time

# %% [markdown]
# Función para dividir el dataset en conjunto de train, test y validation, garantizando que la proporción de patches con y sin deslizamiento se mantiene en todos los conjuntos.

# %%
def patch_has_landslide(patch_file):
    """
    Devuelve:
    - patch_id
    - label_patch: 1 si MASK contiene algún píxel de deslizamiento, 0 si no
    """
    patch_id = os.path.basename(patch_file)

    ds = xr.open_dataset(patch_file)
    mask = ds["MASK"].values
    ds.close()

    label_patch = int(np.nanmax(mask) > 0)

    return patch_id, label_patch


def create_stratified_split(
    patches_dir,
    output_path,
    train_ratio=0.8,
    val_ratio=0.1,
    test_ratio=0.1,
    seed=42,
    n_jobs=-1
):
    """
    Crea split train/val/test estratificado por presencia de deslizamiento.
    """

    assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 1e-6, \
        "Los ratios deben sumar 1."

    patch_files = sorted(glob.glob(os.path.join(patches_dir, "*.nc")))

    print(f"Total patches encontrados: {len(patch_files)}")

    # ---------- LEER LABEL POR PATCH EN PARALELO ----------
    results = Parallel(n_jobs=n_jobs)(
        delayed(patch_has_landslide)(patch_file)
        for patch_file in patch_files
    )

    patch_ids = np.array([r[0] for r in results])
    labels = np.array([r[1] for r in results])

    print("\nDistribución global:")
    print(f" - Con deslizamiento: {np.sum(labels == 1)}")
    print(f" - Sin deslizamiento: {np.sum(labels == 0)}")
    print(f" - Proporción positivos: {np.mean(labels):.3f}")

    # ---------- PRIMER SPLIT: TRAIN vs TEMP ----------
    temp_ratio = val_ratio + test_ratio

    train_ids, temp_ids, y_train, y_temp = train_test_split(
        patch_ids,
        labels,
        test_size=temp_ratio,
        random_state=seed,
        stratify=labels
    )

    # ---------- SEGUNDO SPLIT: VAL vs TEST ----------
    relative_test_ratio = test_ratio / temp_ratio

    val_ids, test_ids, y_val, y_test = train_test_split(
        temp_ids,
        y_temp,
        test_size=relative_test_ratio,
        random_state=seed,
        stratify=y_temp
    )

    split_dict = {
        "train": train_ids.tolist(),
        "val": val_ids.tolist(),
        "test": test_ids.tolist()
    }

    # ---------- GUARDAR ----------
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(split_dict, f, indent=2)

    # ---------- RESUMEN ----------
    def print_split_stats(name, ids, y):
        print(f"\n{name}:")
        print(f" - Total: {len(ids)}")
        print(f" - Con deslizamiento: {np.sum(y == 1)}")
        print(f" - Sin deslizamiento: {np.sum(y == 0)}")
        print(f" - Proporción positivos: {np.mean(y):.3f}")

    print_split_stats("TRAIN", train_ids, y_train)
    print_split_stats("VAL", val_ids, y_val)
    print_split_stats("TEST", test_ids, y_test)

    print(f"\nSplit guardado en: {output_path}")

    return split_dict

# %%
file_patch = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files\Sen2\italy_s2_250_enriched.nc"

patch_has_landslide(file_patch)
# Out:
# ('italy_s2_250_enriched.nc', 0)

# %%
patches_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files\asc"
output_path = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split.json"
create_stratified_split(
    patches_dir,
    output_path,
    train_ratio=0.8,
    val_ratio=0.1,
    test_ratio=0.1,
    seed=42,
    n_jobs=-1
)
# Out:
# Total patches encontrados: 835
#
# Distribución global:
#  - Con deslizamiento: 481
#  - Sin deslizamiento: 354
#  - Proporción positivos: 0.576
#
# TRAIN:
#  - Total: 668
#  - Con deslizamiento: 385
#  - Sin deslizamiento: 283
#  - Proporción positivos: 0.576
#
# VAL:
#  - Total: 83
#  - Con deslizamiento: 48
#  - Sin deslizamiento: 35
#  - Proporción positivos: 0.578
#
# TEST:
#  - Total: 84
#  - Con deslizamiento: 48
#  - Sin deslizamiento: 36
#  - Proporción positivos: 0.571
#
# Split guardado en: C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split.json
# {'train': ['italy_s1asc_3089_enriched.nc',
#   'italy_s1asc_3355_enriched.nc',
#   'italy_s1asc_3509_enriched.nc',
#   'italy_s1asc_3124_enriched.nc',
#   'italy_s1asc_2527_enriched.nc',
#   'italy_s1asc_3004_enriched.nc',
#   'italy_s1asc_3088_enriched.nc',
#   'italy_s1asc_2550_enriched.nc',
#   'italy_s1asc_2687_enriched.nc',
#   'italy_s1asc_322_enriched.nc',
#   'italy_s1asc_2728_enriched.nc',
#   'italy_s1asc_2611_enriched.nc',
#   'italy_s1asc_2934_enriched.nc',
#   'italy_s1asc_3599_enriched.nc',
#   'italy_s1asc_2876_enriched.nc',
#   'italy_s1asc_2985_enriched.nc',
#   'italy_s1asc_3313_enriched.nc',
#   'italy_s1asc_3293_enriched.nc',
#   'italy_s1asc_2669_enriched.nc',
#   'italy_s1asc_2622_enriched.nc',
#   'italy_s1asc_2667_enriched.nc',
#   'italy_s1asc_2641_enriched.nc',
#   'italy_s1asc_3659_enriched.nc',
#   'italy_s1asc_2981_enriched.nc',
#   'italy_s1asc_3187_enriched.nc',
#   'italy_s1asc_3603_enriched.nc',
#   'italy_s1asc_2783_enriched.nc',
#   'italy_s1asc_3371_enriched.nc',
#   'italy_s1asc_3440_enriched.nc',
#   'italy_s1asc_3545_enriched.nc',
#   'italy_s1asc_3185_enriched.nc',
#   'italy_s1asc_2770_enriched.nc',
#   'italy_s1asc_2632_enriched.nc',
#   'italy_s1asc_2873_enriched.nc',
#   'italy_s1asc_2945_enriched.nc',
#   'italy_s1asc_2773_enriched.nc',
#   'italy_s1asc_2734_enriched.nc',
#   'italy_s1asc_2645_enriched.nc',
#   'italy_s1asc_3268_enriched.nc',
#   'italy_s1asc_3459_enriched.nc',
#   'italy_s1asc_3491_enriched.nc',
#   'italy_s1asc_301_enriched.nc',
#   'italy_s1asc_3212_enriched.nc',
#   'italy_s1asc_2548_enriched.nc',
#   'italy_s1asc_3667_enriched.nc',
#   'italy_s1asc_2579_enriched.nc',
#   'italy_s1asc_3437_enriched.nc',
#   'italy_s1asc_3084_enriched.nc',
#   'italy_s1asc_3665_enriched.nc',
#   'italy_s1asc_3383_enriched.nc',
#   'italy_s1asc_3021_enriched.nc',
#   'italy_s1asc_2997_enriched.nc',
#   'italy_s1asc_3058_enriched.nc',
#   'italy_s1asc_2552_enriched.nc',
#   'italy_s1asc_2785_enriched.nc',
#   'italy_s1asc_2660_enriched.nc',
#   'italy_s1asc_2556_enriched.nc',
#   'italy_s1asc_3451_enriched.nc',
#   'italy_s1asc_3675_enriched.nc',
#   'italy_s1asc_2713_enriched.nc',
#   'italy_s1asc_3080_enriched.nc',
#   'italy_s1asc_2689_enriched.nc',
#   'italy_s1asc_3736_enriched.nc',
#   'italy_s1asc_3739_enriched.nc',
#   'italy_s1asc_3633_enriched.nc',
#   'italy_s1asc_2825_enriched.nc',
#   'italy_s1asc_2564_enriched.nc',
#   'italy_s1asc_3310_enriched.nc',
#   'italy_s1asc_3083_enriched.nc',
#   'italy_s1asc_2796_enriched.nc',
#   'italy_s1asc_2524_enriched.nc',
#   'italy_s1asc_2690_enriched.nc',
#   'italy_s1asc_3586_enriched.nc',
#   'italy_s1asc_3514_enriched.nc',
#   'italy_s1asc_359_enriched.nc',
#   'italy_s1asc_2740_enriched.nc',
#   'italy_s1asc_2594_enriched.nc',
#   'italy_s1asc_3081_enriched.nc',
#   'italy_s1asc_3541_enriched.nc',
#   'italy_s1asc_3234_enriched.nc',
#   'italy_s1asc_3559_enriched.nc',
#   'italy_s1asc_2947_enriched.nc',
#   'italy_s1asc_3010_enriched.nc',
#   'italy_s1asc_2797_enriched.nc',
#   'italy_s1asc_3138_enriched.nc',
#   'italy_s1asc_3027_enriched.nc',
#   'italy_s1asc_3542_enriched.nc',
#   'italy_s1asc_3738_enriched.nc',
#   'italy_s1asc_287_enriched.nc',
#   'italy_s1asc_3715_enriched.nc',
#   'italy_s1asc_3317_enriched.nc',
#   'italy_s1asc_257_enriched.nc',
#   'italy_s1asc_3503_enriched.nc',
#   'italy_s1asc_3288_enriched.nc',
#   'italy_s1asc_2535_enriched.nc',
#   'italy_s1asc_2853_enriched.nc',
#   'italy_s1asc_3521_enriched.nc',
#   'italy_s1asc_2570_enriched.nc',
#   'italy_s1asc_2815_enriched.nc',
#   'italy_s1asc_2577_enriched.nc',
#   'italy_s1asc_2906_enriched.nc',
#   'italy_s1asc_3637_enriched.nc',
#   'italy_s1asc_2630_enriched.nc',
#   'italy_s1asc_2780_enriched.nc',
#   'italy_s1asc_3727_enriched.nc',
#   'italy_s1asc_3155_enriched.nc',
#   'italy_s1asc_3067_enriched.nc',
#   'italy_s1asc_3535_enriched.nc',
#   'italy_s1asc_2533_enriched.nc',
#   'italy_s1asc_2511_enriched.nc',
#   'italy_s1asc_3620_enriched.nc',
#   'italy_s1asc_2507_enriched.nc',
#   'italy_s1asc_3482_enriched.nc',
#   'italy_s1asc_3717_enriched.nc',
#   'italy_s1asc_3668_enriched.nc',
#   'italy_s1asc_3071_enriched.nc',
#   'italy_s1asc_3102_enriched.nc',
#   'italy_s1asc_3649_enriched.nc',
#   'italy_s1asc_3737_enriched.nc',
#   'italy_s1asc_3291_enriched.nc',
#   'italy_s1asc_281_enriched.nc',
#   'italy_s1asc_3448_enriched.nc',
#   'italy_s1asc_3135_enriched.nc',
#   'italy_s1asc_3338_enriched.nc',
#   'italy_s1asc_3587_enriched.nc',
#   'italy_s1asc_360_enriched.nc',
#   'italy_s1asc_3441_enriched.nc',
#   'italy_s1asc_2937_enriched.nc',
#   'italy_s1asc_342_enriched.nc',
#   'italy_s1asc_2864_enriched.nc',
#   'italy_s1asc_2863_enriched.nc',
#   'italy_s1asc_3303_enriched.nc',
#   'italy_s1asc_3664_enriched.nc',
#   'italy_s1asc_3072_enriched.nc',
#   'italy_s1asc_2679_enriched.nc',
#   'italy_s1asc_2616_enriched.nc',
#   'italy_s1asc_2521_enriched.nc',
#   'italy_s1asc_2557_enriched.nc',
#   'italy_s1asc_2706_enriched.nc',
#   'italy_s1asc_280_enriched.nc',
#   'italy_s1asc_3713_enriched.nc',
#   'italy_s1asc_3006_enriched.nc',
#   'italy_s1asc_2866_enriched.nc',
#   'italy_s1asc_3283_enriched.nc',
#   'italy_s1asc_3297_enriched.nc',
#   'italy_s1asc_3145_enriched.nc',
#   'italy_s1asc_2573_enriched.nc',
#   'italy_s1asc_2882_enriched.nc',
#   'italy_s1asc_2828_enriched.nc',
#   'italy_s1asc_2816_enriched.nc',
#   'italy_s1asc_3082_enriched.nc',
#   'italy_s1asc_2907_enriched.nc',
#   'italy_s1asc_2525_enriched.nc',
#   'italy_s1asc_2903_enriched.nc',
#   'italy_s1asc_2600_enriched.nc',
#   'italy_s1asc_3312_enriched.nc',
#   'italy_s1asc_266_enriched.nc',
#   'italy_s1asc_2659_enriched.nc',
#   'italy_s1asc_2741_enriched.nc',
#   'italy_s1asc_3515_enriched.nc',
#   'italy_s1asc_3075_enriched.nc',
#   'italy_s1asc_3734_enriched.nc',
#   'italy_s1asc_2561_enriched.nc',
#   'italy_s1asc_2768_enriched.nc',
#   'italy_s1asc_2707_enriched.nc',
#   'italy_s1asc_3373_enriched.nc',
#   'italy_s1asc_3711_enriched.nc',
#   'italy_s1asc_3597_enriched.nc',
#   'italy_s1asc_2721_enriched.nc',
#   'italy_s1asc_2708_enriched.nc',
#   'italy_s1asc_3149_enriched.nc',
#   'italy_s1asc_3146_enriched.nc',
#   'italy_s1asc_2860_enriched.nc',
#   'italy_s1asc_3480_enriched.nc',
#   'italy_s1asc_3156_enriched.nc',
#   'italy_s1asc_2701_enriched.nc',
#   'italy_s1asc_3530_enriched.nc',
#   'italy_s1asc_2742_enriched.nc',
#   'italy_s1asc_3026_enriched.nc',
#   'italy_s1asc_2636_enriched.nc',
#   'italy_s1asc_3372_enriched.nc',
#   'italy_s1asc_3677_enriched.nc',
#   'italy_s1asc_3417_enriched.nc',
#   'italy_s1asc_3307_enriched.nc',
#   'italy_s1asc_3595_enriched.nc',
#   'italy_s1asc_2638_enriched.nc',
#   'italy_s1asc_3206_enriched.nc',
#   'italy_s1asc_2628_enriched.nc',
#   'italy_s1asc_2572_enriched.nc',
#   'italy_s1asc_3002_enriched.nc',
#   'italy_s1asc_3380_enriched.nc',
#   'italy_s1asc_269_enriched.nc',
#   'italy_s1asc_277_enriched.nc',
#   'italy_s1asc_3593_enriched.nc',
#   'italy_s1asc_2978_enriched.nc',
#   'italy_s1asc_3458_enriched.nc',
#   'italy_s1asc_3532_enriched.nc',
#   'italy_s1asc_3673_enriched.nc',
#   'italy_s1asc_2731_enriched.nc',
#   'italy_s1asc_3172_enriched.nc',
#   'italy_s1asc_3078_enriched.nc',
#   'italy_s1asc_303_enriched.nc',
#   'italy_s1asc_262_enriched.nc',
#   'italy_s1asc_2558_enriched.nc',
#   'italy_s1asc_3596_enriched.nc',
#   'italy_s1asc_3186_enriched.nc',
#   'italy_s1asc_2510_enriched.nc',
#   'italy_s1asc_3424_enriched.nc',
#   'italy_s1asc_3153_enriched.nc',
#   'italy_s1asc_2575_enriched.nc',
#   'italy_s1asc_3309_enriched.nc',
#   'italy_s1asc_358_enriched.nc',
#   'italy_s1asc_2694_enriched.nc',
#   'italy_s1asc_2586_enriched.nc',
#   'italy_s1asc_3663_enriched.nc',
#   'italy_s1asc_3007_enriched.nc',
#   'italy_s1asc_2729_enriched.nc',
#   'italy_s1asc_3070_enriched.nc',
#   'italy_s1asc_2928_enriched.nc',
#   'italy_s1asc_3065_enriched.nc',
#   'italy_s1asc_2772_enriched.nc',
#   'italy_s1asc_3000_enriched.nc',
#   'italy_s1asc_2670_enriched.nc',
#   'italy_s1asc_3167_enriched.nc',
#   'italy_s1asc_278_enriched.nc',
#   'italy_s1asc_2755_enriched.nc',
#   'italy_s1asc_2725_enriched.nc',
#   'italy_s1asc_2541_enriched.nc',
#   'italy_s1asc_3118_enriched.nc',
#   'italy_s1asc_297_enriched.nc',
#   'italy_s1asc_2799_enriched.nc',
#   'italy_s1asc_2857_enriched.nc',
#   'italy_s1asc_3612_enriched.nc',
#   'italy_s1asc_3361_enriched.nc',
#   'italy_s1asc_3213_enriched.nc',
#   'italy_s1asc_2841_enriched.nc',
#   'italy_s1asc_3348_enriched.nc',
#   'italy_s1asc_2877_enriched.nc',
#   'italy_s1asc_3271_enriched.nc',
#   'italy_s1asc_3214_enriched.nc',
#   'italy_s1asc_2748_enriched.nc',
#   'italy_s1asc_3445_enriched.nc',
#   'italy_s1asc_2723_enriched.nc',
#   'italy_s1asc_2908_enriched.nc',
#   'italy_s1asc_2925_enriched.nc',
#   'italy_s1asc_3306_enriched.nc',
#   'italy_s1asc_3590_enriched.nc',
#   'italy_s1asc_3454_enriched.nc',
#   'italy_s1asc_3366_enriched.nc',
#   'italy_s1asc_345_enriched.nc',
#   'italy_s1asc_3601_enriched.nc',
#   'italy_s1asc_3095_enriched.nc',
#   'italy_s1asc_3653_enriched.nc',
#   'italy_s1asc_2695_enriched.nc',
#   'italy_s1asc_3226_enriched.nc',
#   'italy_s1asc_2865_enriched.nc',
#   'italy_s1asc_3442_enriched.nc',
#   'italy_s1asc_3261_enriched.nc',
#   'italy_s1asc_3334_enriched.nc',
#   'italy_s1asc_2966_enriched.nc',
#   'italy_s1asc_2926_enriched.nc',
#   'italy_s1asc_2803_enriched.nc',
#   'italy_s1asc_2919_enriched.nc',
#   'italy_s1asc_353_enriched.nc',
#   'italy_s1asc_3421_enriched.nc',
#   'italy_s1asc_3139_enriched.nc',
#   'italy_s1asc_3176_enriched.nc',
#   'italy_s1asc_2941_enriched.nc',
#   'italy_s1asc_2834_enriched.nc',
#   'italy_s1asc_2606_enriched.nc',
#   'italy_s1asc_2520_enriched.nc',
#   'italy_s1asc_3189_enriched.nc',
#   'italy_s1asc_2598_enriched.nc',
#   'italy_s1asc_2538_enriched.nc',
#   'italy_s1asc_3277_enriched.nc',
#   'italy_s1asc_3572_enriched.nc',
#   'italy_s1asc_2766_enriched.nc',
#   'italy_s1asc_3522_enriched.nc',
#   'italy_s1asc_3163_enriched.nc',
#   'italy_s1asc_3390_enriched.nc',
#   'italy_s1asc_2568_enriched.nc',
#   'italy_s1asc_2782_enriched.nc',
#   'italy_s1asc_2932_enriched.nc',
#   'italy_s1asc_2832_enriched.nc',
#   'italy_s1asc_3588_enriched.nc',
#   'italy_s1asc_2983_enriched.nc',
#   'italy_s1asc_2905_enriched.nc',
#   'italy_s1asc_3085_enriched.nc',
#   'italy_s1asc_2918_enriched.nc',
#   'italy_s1asc_3091_enriched.nc',
#   'italy_s1asc_3511_enriched.nc',
#   'italy_s1asc_3536_enriched.nc',
#   'italy_s1asc_3655_enriched.nc',
#   'italy_s1asc_3159_enriched.nc',
#   'italy_s1asc_339_enriched.nc',
#   'italy_s1asc_2724_enriched.nc',
#   'italy_s1asc_3192_enriched.nc',
#   'italy_s1asc_3577_enriched.nc',
#   'italy_s1asc_3534_enriched.nc',
#   'italy_s1asc_3436_enriched.nc',
#   'italy_s1asc_364_enriched.nc',
#   'italy_s1asc_2844_enriched.nc',
#   'italy_s1asc_323_enriched.nc',
#   'italy_s1asc_2949_enriched.nc',
#   'italy_s1asc_3427_enriched.nc',
#   'italy_s1asc_2944_enriched.nc',
#   'italy_s1asc_3245_enriched.nc',
#   'italy_s1asc_3434_enriched.nc',
#   'italy_s1asc_3573_enriched.nc',
#   'italy_s1asc_3516_enriched.nc',
#   'italy_s1asc_3054_enriched.nc',
#   'italy_s1asc_2585_enriched.nc',
#   'italy_s1asc_2727_enriched.nc',
#   'italy_s1asc_2637_enriched.nc',
#   'italy_s1asc_3526_enriched.nc',
#   'italy_s1asc_2595_enriched.nc',
#   'italy_s1asc_3219_enriched.nc',
#   'italy_s1asc_3008_enriched.nc',
#   'italy_s1asc_2923_enriched.nc',
#   'italy_s1asc_3702_enriched.nc',
#   'italy_s1asc_3683_enriched.nc',
#   'italy_s1asc_3017_enriched.nc',
#   'italy_s1asc_3224_enriched.nc',
#   'italy_s1asc_2623_enriched.nc',
#   'italy_s1asc_2681_enriched.nc',
#   'italy_s1asc_2522_enriched.nc',
#   'italy_s1asc_2555_enriched.nc',
#   'italy_s1asc_3098_enriched.nc',
#   'italy_s1asc_2672_enriched.nc',
#   'italy_s1asc_2990_enriched.nc',
#   'italy_s1asc_3042_enriched.nc',
#   'italy_s1asc_3386_enriched.nc',
#   'italy_s1asc_3438_enriched.nc',
#   'italy_s1asc_2567_enriched.nc',
#   'italy_s1asc_3286_enriched.nc',
#   'italy_s1asc_3169_enriched.nc',
#   'italy_s1asc_3730_enriched.nc',
#   'italy_s1asc_3523_enriched.nc',
#   'italy_s1asc_2704_enriched.nc',
#   'italy_s1asc_2823_enriched.nc',
#   'italy_s1asc_3151_enriched.nc',
#   'italy_s1asc_2614_enriched.nc',
#   'italy_s1asc_2914_enriched.nc',
#   'italy_s1asc_3227_enriched.nc',
#   'italy_s1asc_3488_enriched.nc',
#   'italy_s1asc_2711_enriched.nc',
#   'italy_s1asc_3682_enriched.nc',
#   'italy_s1asc_3264_enriched.nc',
#   'italy_s1asc_2847_enriched.nc',
#   'italy_s1asc_3150_enriched.nc',
#   'italy_s1asc_3594_enriched.nc',
#   'italy_s1asc_3263_enriched.nc',
#   'italy_s1asc_2503_enriched.nc',
#   'italy_s1asc_3430_enriched.nc',
#   'italy_s1asc_3377_enriched.nc',
#   'italy_s1asc_3592_enriched.nc',
#   'italy_s1asc_325_enriched.nc',
#   'italy_s1asc_3030_enriched.nc',
#   'italy_s1asc_3148_enriched.nc',
#   'italy_s1asc_3600_enriched.nc',
#   'italy_s1asc_2699_enriched.nc',
#   'italy_s1asc_3300_enriched.nc',
#   'italy_s1asc_3519_enriched.nc',
#   'italy_s1asc_2995_enriched.nc',
#   'italy_s1asc_3680_enriched.nc',
#   'italy_s1asc_3505_enriched.nc',
#   'italy_s1asc_3011_enriched.nc',
#   'italy_s1asc_2931_enriched.nc',
#   'italy_s1asc_2543_enriched.nc',
#   'italy_s1asc_2892_enriched.nc',
#   'italy_s1asc_2566_enriched.nc',
#   'italy_s1asc_2692_enriched.nc',
#   'italy_s1asc_2862_enriched.nc',
#   'italy_s1asc_3064_enriched.nc',
#   'italy_s1asc_2912_enriched.nc',
#   'italy_s1asc_3243_enriched.nc',
#   'italy_s1asc_3634_enriched.nc',
#   'italy_s1asc_3302_enriched.nc',
#   'italy_s1asc_3231_enriched.nc',
#   'italy_s1asc_3232_enriched.nc',
#   'italy_s1asc_2831_enriched.nc',
#   'italy_s1asc_3578_enriched.nc',
#   'italy_s1asc_3381_enriched.nc',
#   'italy_s1asc_3565_enriched.nc',
#   'italy_s1asc_2560_enriched.nc',
#   'italy_s1asc_3235_enriched.nc',
#   'italy_s1asc_3266_enriched.nc',
#   'italy_s1asc_3239_enriched.nc',
#   'italy_s1asc_3161_enriched.nc',
#   'italy_s1asc_3684_enriched.nc',
#   'italy_s1asc_254_enriched.nc',
#   'italy_s1asc_3422_enriched.nc',
#   'italy_s1asc_2717_enriched.nc',
#   'italy_s1asc_2791_enriched.nc',
#   'italy_s1asc_2822_enriched.nc',
#   'italy_s1asc_3721_enriched.nc',
#   'italy_s1asc_3643_enriched.nc',
#   'italy_s1asc_2858_enriched.nc',
#   'italy_s1asc_3359_enriched.nc',
#   'italy_s1asc_3608_enriched.nc',
#   'italy_s1asc_3689_enriched.nc',
#   'italy_s1asc_3510_enriched.nc',
#   'italy_s1asc_3525_enriched.nc',
#   'italy_s1asc_3337_enriched.nc',
#   'italy_s1asc_2502_enriched.nc',
#   'italy_s1asc_3090_enriched.nc',
#   'italy_s1asc_268_enriched.nc',
#   'italy_s1asc_2893_enriched.nc',
#   'italy_s1asc_2872_enriched.nc',
#   'italy_s1asc_3059_enriched.nc',
#   'italy_s1asc_3104_enriched.nc',
#   'italy_s1asc_2554_enriched.nc',
#   'italy_s1asc_2929_enriched.nc',
#   'italy_s1asc_2920_enriched.nc',
#   'italy_s1asc_3607_enriched.nc',
#   'italy_s1asc_3662_enriched.nc',
#   'italy_s1asc_2777_enriched.nc',
#   'italy_s1asc_3576_enriched.nc',
#   'italy_s1asc_2705_enriched.nc',
#   'italy_s1asc_2714_enriched.nc',
#   'italy_s1asc_346_enriched.nc',
#   'italy_s1asc_2644_enriched.nc',
#   'italy_s1asc_2719_enriched.nc',
#   'italy_s1asc_2732_enriched.nc',
#   'italy_s1asc_2765_enriched.nc',
#   'italy_s1asc_3301_enriched.nc',
#   'italy_s1asc_3429_enriched.nc',
#   'italy_s1asc_3672_enriched.nc',
#   'italy_s1asc_2943_enriched.nc',
#   'italy_s1asc_3518_enriched.nc',
#   'italy_s1asc_3019_enriched.nc',
#   'italy_s1asc_3223_enriched.nc',
#   'italy_s1asc_2846_enriched.nc',
#   'italy_s1asc_3602_enriched.nc',
#   'italy_s1asc_3014_enriched.nc',
#   'italy_s1asc_2817_enriched.nc',
#   'italy_s1asc_3679_enriched.nc',
#   'italy_s1asc_350_enriched.nc',
#   'italy_s1asc_2942_enriched.nc',
#   'italy_s1asc_2634_enriched.nc',
#   'italy_s1asc_2787_enriched.nc',
#   'italy_s1asc_2870_enriched.nc',
#   'italy_s1asc_3408_enriched.nc',
#   'italy_s1asc_3382_enriched.nc',
#   'italy_s1asc_3676_enriched.nc',
#   'italy_s1asc_3709_enriched.nc',
#   'italy_s1asc_3166_enriched.nc',
#   'italy_s1asc_3230_enriched.nc',
#   'italy_s1asc_351_enriched.nc',
#   'italy_s1asc_3670_enriched.nc',
#   'italy_s1asc_3456_enriched.nc',
#   'italy_s1asc_3466_enriched.nc',
#   'italy_s1asc_267_enriched.nc',
#   'italy_s1asc_279_enriched.nc',
#   'italy_s1asc_2930_enriched.nc',
#   'italy_s1asc_2933_enriched.nc',
#   'italy_s1asc_3294_enriched.nc',
#   'italy_s1asc_2969_enriched.nc',
#   'italy_s1asc_2722_enriched.nc',
#   'italy_s1asc_2702_enriched.nc',
#   'italy_s1asc_3452_enriched.nc',
#   'italy_s1asc_3513_enriched.nc',
#   'italy_s1asc_3287_enriched.nc',
#   'italy_s1asc_3204_enriched.nc',
#   'italy_s1asc_3528_enriched.nc',
#   'italy_s1asc_3376_enriched.nc',
#   'italy_s1asc_285_enriched.nc',
#   'italy_s1asc_2534_enriched.nc',
#   'italy_s1asc_2648_enriched.nc',
#   'italy_s1asc_311_enriched.nc',
#   'italy_s1asc_2927_enriched.nc',
#   'italy_s1asc_3092_enriched.nc',
#   'italy_s1asc_3732_enriched.nc',
#   'italy_s1asc_2639_enriched.nc',
#   'italy_s1asc_2875_enriched.nc',
#   'italy_s1asc_2837_enriched.nc',
#   'italy_s1asc_2798_enriched.nc',
#   'italy_s1asc_3217_enriched.nc',
#   'italy_s1asc_3285_enriched.nc',
#   'italy_s1asc_3157_enriched.nc',
#   'italy_s1asc_2563_enriched.nc',
#   'italy_s1asc_3585_enriched.nc',
#   'italy_s1asc_3063_enriched.nc',
#   'italy_s1asc_2779_enriched.nc',
#   'italy_s1asc_3635_enriched.nc',
#   'italy_s1asc_3568_enriched.nc',
#   'italy_s1asc_3009_enriched.nc',
#   'italy_s1asc_3379_enriched.nc',
#   'italy_s1asc_2574_enriched.nc',
#   'italy_s1asc_356_enriched.nc',
#   'italy_s1asc_3666_enriched.nc',
#   'italy_s1asc_3610_enriched.nc',
#   'italy_s1asc_3605_enriched.nc',
#   'italy_s1asc_344_enriched.nc',
#   'italy_s1asc_2793_enriched.nc',
#   'italy_s1asc_3158_enriched.nc',
#   'italy_s1asc_2682_enriched.nc',
#   'italy_s1asc_3378_enriched.nc',
#   'italy_s1asc_3467_enriched.nc',
#   'italy_s1asc_3468_enriched.nc',
#   'italy_s1asc_3282_enriched.nc',
#   'italy_s1asc_2789_enriched.nc',
#   'italy_s1asc_3144_enriched.nc',
#   'italy_s1asc_3407_enriched.nc',
#   'italy_s1asc_2820_enriched.nc',
#   'italy_s1asc_2635_enriched.nc',
#   'italy_s1asc_3547_enriched.nc',
#   'italy_s1asc_3120_enriched.nc',
#   'italy_s1asc_3020_enriched.nc',
#   'italy_s1asc_3388_enriched.nc',
#   'italy_s1asc_3164_enriched.nc',
#   'italy_s1asc_3012_enriched.nc',
#   'italy_s1asc_2814_enriched.nc',
#   'italy_s1asc_255_enriched.nc',
#   'italy_s1asc_251_enriched.nc',
#   'italy_s1asc_2697_enriched.nc',
#   'italy_s1asc_2565_enriched.nc',
#   'italy_s1asc_2856_enriched.nc',
#   'italy_s1asc_2654_enriched.nc',
#   'italy_s1asc_3540_enriched.nc',
#   'italy_s1asc_2794_enriched.nc',
#   'italy_s1asc_3543_enriched.nc',
#   'italy_s1asc_2559_enriched.nc',
#   'italy_s1asc_2633_enriched.nc',
#   'italy_s1asc_2859_enriched.nc',
#   'italy_s1asc_2718_enriched.nc',
#   'italy_s1asc_2992_enriched.nc',
#   'italy_s1asc_3236_enriched.nc',
#   'italy_s1asc_3165_enriched.nc',
#   'italy_s1asc_3604_enriched.nc',
#   'italy_s1asc_283_enriched.nc',
#   'italy_s1asc_2604_enriched.nc',
#   'italy_s1asc_3315_enriched.nc',
#   'italy_s1asc_3484_enriched.nc',
#   'italy_s1asc_3142_enriched.nc',
#   'italy_s1asc_3241_enriched.nc',
#   'italy_s1asc_347_enriched.nc',
#   'italy_s1asc_3237_enriched.nc',
#   'italy_s1asc_334_enriched.nc',
#   'italy_s1asc_3722_enriched.nc',
#   'italy_s1asc_326_enriched.nc',
#   'italy_s1asc_2619_enriched.nc',
#   'italy_s1asc_3685_enriched.nc',
#   'italy_s1asc_3199_enriched.nc',
#   'italy_s1asc_2640_enriched.nc',
#   'italy_s1asc_3335_enriched.nc',
#   'italy_s1asc_2784_enriched.nc',
#   'italy_s1asc_3399_enriched.nc',
#   'italy_s1asc_320_enriched.nc',
#   'italy_s1asc_3384_enriched.nc',
#   'italy_s1asc_2956_enriched.nc',
#   'italy_s1asc_2940_enriched.nc',
#   'italy_s1asc_2910_enriched.nc',
#   'italy_s1asc_3016_enriched.nc',
#   'italy_s1asc_3529_enriched.nc',
#   'italy_s1asc_3508_enriched.nc',
#   'italy_s1asc_2938_enriched.nc',
#   'italy_s1asc_332_enriched.nc',
#   'italy_s1asc_3657_enriched.nc',
#   'italy_s1asc_3374_enriched.nc',
#   'italy_s1asc_3385_enriched.nc',
#   'italy_s1asc_3134_enriched.nc',
#   'italy_s1asc_2935_enriched.nc',
#   'italy_s1asc_3656_enriched.nc',
#   'italy_s1asc_2804_enriched.nc',
#   'italy_s1asc_3074_enriched.nc',
#   'italy_s1asc_307_enriched.nc',
#   'italy_s1asc_3731_enriched.nc',
#   'italy_s1asc_3512_enriched.nc',
#   'italy_s1asc_3418_enriched.nc',
#   'italy_s1asc_2553_enriched.nc',
#   'italy_s1asc_355_enriched.nc',
#   'italy_s1asc_3400_enriched.nc',
#   'italy_s1asc_274_enriched.nc',
#   'italy_s1asc_3094_enriched.nc',
#   'italy_s1asc_290_enriched.nc',
#   'italy_s1asc_3350_enriched.nc',
#   'italy_s1asc_2776_enriched.nc',
#   'italy_s1asc_3160_enriched.nc',
#   'italy_s1asc_3446_enriched.nc',
#   'italy_s1asc_3387_enriched.nc',
#   'italy_s1asc_2948_enriched.nc',
#   'italy_s1asc_3389_enriched.nc',
#   'italy_s1asc_2531_enriched.nc',
#   'italy_s1asc_3069_enriched.nc',
#   'italy_s1asc_3447_enriched.nc',
#   'italy_s1asc_2712_enriched.nc',
#   'italy_s1asc_3292_enriched.nc',
#   'italy_s1asc_3304_enriched.nc',
#   'italy_s1asc_2991_enriched.nc',
#   'italy_s1asc_3202_enriched.nc',
#   'italy_s1asc_2861_enriched.nc',
#   'italy_s1asc_3368_enriched.nc',
#   'italy_s1asc_3581_enriched.nc',
#   'italy_s1asc_3154_enriched.nc',
#   'italy_s1asc_2626_enriched.nc',
#   'italy_s1asc_2951_enriched.nc',
#   'italy_s1asc_3023_enriched.nc',
#   'italy_s1asc_361_enriched.nc',
#   'italy_s1asc_288_enriched.nc',
#   'italy_s1asc_2974_enriched.nc',
#   'italy_s1asc_2685_enriched.nc',
#   'italy_s1asc_337_enriched.nc',
#   'italy_s1asc_3077_enriched.nc',
#   'italy_s1asc_3712_enriched.nc',
#   'italy_s1asc_2720_enriched.nc',
#   'italy_s1asc_2562_enriched.nc',
#   'italy_s1asc_2984_enriched.nc',
#   'italy_s1asc_352_enriched.nc',
#   'italy_s1asc_3233_enriched.nc',
#   'italy_s1asc_2754_enriched.nc',
#   'italy_s1asc_3216_enriched.nc',
#   'italy_s1asc_3322_enriched.nc',
#   'italy_s1asc_3453_enriched.nc',
#   'italy_s1asc_3562_enriched.nc',
#   'italy_s1asc_2758_enriched.nc',
#   'italy_s1asc_2900_enriched.nc',
#   'italy_s1asc_2757_enriched.nc',
#   'italy_s1asc_2504_enriched.nc',
#   'italy_s1asc_3076_enriched.nc',
#   'italy_s1asc_250_enriched.nc',
#   'italy_s1asc_2833_enriched.nc',
#   'italy_s1asc_3681_enriched.nc',
#   'italy_s1asc_2879_enriched.nc',
#   'italy_s1asc_270_enriched.nc',
#   'italy_s1asc_3520_enriched.nc',
#   'italy_s1asc_3660_enriched.nc',
#   'italy_s1asc_3474_enriched.nc',
#   'italy_s1asc_2532_enriched.nc',
#   'italy_s1asc_2624_enriched.nc',
#   'italy_s1asc_3162_enriched.nc',
#   'italy_s1asc_357_enriched.nc',
#   'italy_s1asc_3671_enriched.nc',
#   'italy_s1asc_3691_enriched.nc',
#   'italy_s1asc_3013_enriched.nc',
#   'italy_s1asc_3582_enriched.nc',
#   'italy_s1asc_3589_enriched.nc',
#   'italy_s1asc_2576_enriched.nc',
#   'italy_s1asc_3079_enriched.nc',
#   'italy_s1asc_3533_enriched.nc',
#   'italy_s1asc_2571_enriched.nc',
#   'italy_s1asc_3546_enriched.nc',
#   'italy_s1asc_2627_enriched.nc',
#   'italy_s1asc_2655_enriched.nc',
#   'italy_s1asc_3049_enriched.nc',
#   'italy_s1asc_3431_enriched.nc',
#   'italy_s1asc_3606_enriched.nc',
#   'italy_s1asc_3290_enriched.nc',
#   'italy_s1asc_2518_enriched.nc',
#   'italy_s1asc_3496_enriched.nc',
#   'italy_s1asc_3733_enriched.nc',
#   'italy_s1asc_324_enriched.nc',
#   'italy_s1asc_317_enriched.nc',
#   'italy_s1asc_3621_enriched.nc',
#   'italy_s1asc_256_enriched.nc',
#   'italy_s1asc_2653_enriched.nc',
#   'italy_s1asc_3613_enriched.nc',
#   'italy_s1asc_3174_enriched.nc',
#   'italy_s1asc_3024_enriched.nc',
#   'italy_s1asc_341_enriched.nc',
#   'italy_s1asc_3052_enriched.nc',
#   'italy_s1asc_2795_enriched.nc',
#   'italy_s1asc_3003_enriched.nc',
#   'italy_s1asc_3066_enriched.nc',
#   'italy_s1asc_3609_enriched.nc',
#   'italy_s1asc_2710_enriched.nc',
#   'italy_s1asc_2716_enriched.nc',
#   'italy_s1asc_3087_enriched.nc'],
#  'val': ['italy_s1asc_3113_enriched.nc',
#   'italy_s1asc_3556_enriched.nc',
#   'italy_s1asc_3658_enriched.nc',
#   'italy_s1asc_3238_enriched.nc',
#   'italy_s1asc_2703_enriched.nc',
#   'italy_s1asc_2939_enriched.nc',
#   'italy_s1asc_3040_enriched.nc',
#   'italy_s1asc_2806_enriched.nc',
#   'italy_s1asc_253_enriched.nc',
#   'italy_s1asc_2998_enriched.nc',
#   'italy_s1asc_2657_enriched.nc',
#   'italy_s1asc_2743_enriched.nc',
#   'italy_s1asc_3463_enriched.nc',
#   'italy_s1asc_3391_enriched.nc',
#   'italy_s1asc_3718_enriched.nc',
#   'italy_s1asc_3444_enriched.nc',
#   'italy_s1asc_2643_enriched.nc',
#   'italy_s1asc_2508_enriched.nc',
#   'italy_s1asc_3720_enriched.nc',
#   'italy_s1asc_3228_enriched.nc',
#   'italy_s1asc_340_enriched.nc',
#   'italy_s1asc_3735_enriched.nc',
#   'italy_s1asc_3723_enriched.nc',
#   'italy_s1asc_2874_enriched.nc',
#   'italy_s1asc_2965_enriched.nc',
#   'italy_s1asc_2631_enriched.nc',
#   'italy_s1asc_2709_enriched.nc',
#   'italy_s1asc_3461_enriched.nc',
#   'italy_s1asc_2582_enriched.nc',
#   'italy_s1asc_3281_enriched.nc',
#   'italy_s1asc_2642_enriched.nc',
#   'italy_s1asc_3171_enriched.nc',
#   'italy_s1asc_2647_enriched.nc',
#   'italy_s1asc_2835_enriched.nc',
#   'italy_s1asc_2629_enriched.nc',
#   'italy_s1asc_3375_enriched.nc',
#   'italy_s1asc_3308_enriched.nc',
#   'italy_s1asc_3055_enriched.nc',
#   'italy_s1asc_2805_enriched.nc',
#   'italy_s1asc_3439_enriched.nc',
#   'italy_s1asc_3190_enriched.nc',
#   'italy_s1asc_2774_enriched.nc',
#   'italy_s1asc_2652_enriched.nc',
#   'italy_s1asc_2700_enriched.nc',
#   'italy_s1asc_2842_enriched.nc',
#   'italy_s1asc_2746_enriched.nc',
#   'italy_s1asc_3548_enriched.nc',
#   'italy_s1asc_372_enriched.nc',
#   'italy_s1asc_2792_enriched.nc',
#   'italy_s1asc_2715_enriched.nc',
#   'italy_s1asc_2625_enriched.nc',
#   'italy_s1asc_3341_enriched.nc',
#   'italy_s1asc_286_enriched.nc',
#   'italy_s1asc_2850_enriched.nc',
#   'italy_s1asc_3435_enriched.nc',
#   'italy_s1asc_2688_enriched.nc',
#   'italy_s1asc_3455_enriched.nc',
#   'italy_s1asc_2852_enriched.nc',
#   'italy_s1asc_3225_enriched.nc',
#   'italy_s1asc_2851_enriched.nc',
#   'italy_s1asc_2924_enriched.nc',
#   'italy_s1asc_3619_enriched.nc',
#   'italy_s1asc_2651_enriched.nc',
#   'italy_s1asc_3460_enriched.nc',
#   'italy_s1asc_3114_enriched.nc',
#   'italy_s1asc_3661_enriched.nc',
#   'italy_s1asc_3222_enriched.nc',
#   'italy_s1asc_2869_enriched.nc',
#   'italy_s1asc_3152_enriched.nc',
#   'italy_s1asc_310_enriched.nc',
#   'italy_s1asc_3001_enriched.nc',
#   'italy_s1asc_3111_enriched.nc',
#   'italy_s1asc_2569_enriched.nc',
#   'italy_s1asc_289_enriched.nc',
#   'italy_s1asc_3729_enriched.nc',
#   'italy_s1asc_3086_enriched.nc',
#   'italy_s1asc_2894_enriched.nc',
#   'italy_s1asc_3415_enriched.nc',
#   'italy_s1asc_3517_enriched.nc',
#   'italy_s1asc_3367_enriched.nc',
#   'italy_s1asc_2620_enriched.nc',
#   'italy_s1asc_2855_enriched.nc',
#   'italy_s1asc_2946_enriched.nc'],
#  'test': ['italy_s1asc_2936_enriched.nc',
#   'italy_s1asc_2730_enriched.nc',
#   'italy_s1asc_2769_enriched.nc',
#   'italy_s1asc_3137_enriched.nc',
#   'italy_s1asc_3184_enriched.nc',
#   'italy_s1asc_3358_enriched.nc',
#   'italy_s1asc_2867_enriched.nc',
#   'italy_s1asc_2650_enriched.nc',
#   'italy_s1asc_3678_enriched.nc',
#   'italy_s1asc_3423_enriched.nc',
#   'italy_s1asc_3524_enriched.nc',
#   'italy_s1asc_3229_enriched.nc',
#   'italy_s1asc_3443_enriched.nc',
#   'italy_s1asc_3203_enriched.nc',
#   'italy_s1asc_3569_enriched.nc',
#   'italy_s1asc_2800_enriched.nc',
#   'italy_s1asc_3005_enriched.nc',
#   'italy_s1asc_3598_enriched.nc',
#   'italy_s1asc_2801_enriched.nc',
#   'italy_s1asc_2917_enriched.nc',
#   'italy_s1asc_2986_enriched.nc',
#   'italy_s1asc_2871_enriched.nc',
#   'italy_s1asc_2649_enriched.nc',
#   'italy_s1asc_3168_enriched.nc',
#   'italy_s1asc_3240_enriched.nc',
#   'italy_s1asc_282_enriched.nc',
#   'italy_s1asc_2778_enriched.nc',
#   'italy_s1asc_300_enriched.nc',
#   'italy_s1asc_3370_enriched.nc',
#   'italy_s1asc_3279_enriched.nc',
#   'italy_s1asc_3369_enriched.nc',
#   'italy_s1asc_263_enriched.nc',
#   'italy_s1asc_336_enriched.nc',
#   'italy_s1asc_3140_enriched.nc',
#   'italy_s1asc_3413_enriched.nc',
#   'italy_s1asc_2501_enriched.nc',
#   'italy_s1asc_3211_enriched.nc',
#   'italy_s1asc_2751_enriched.nc',
#   'italy_s1asc_3531_enriched.nc',
#   'italy_s1asc_3117_enriched.nc',
#   'italy_s1asc_3029_enriched.nc',
#   'italy_s1asc_3068_enriched.nc',
#   'italy_s1asc_3419_enriched.nc',
#   'italy_s1asc_3502_enriched.nc',
#   'italy_s1asc_3591_enriched.nc',
#   'italy_s1asc_3298_enriched.nc',
#   'italy_s1asc_3462_enriched.nc',
#   'italy_s1asc_343_enriched.nc',
#   'italy_s1asc_2868_enriched.nc',
#   'italy_s1asc_3221_enriched.nc',
#   'italy_s1asc_3728_enriched.nc',
#   'italy_s1asc_3218_enriched.nc',
#   'italy_s1asc_3669_enriched.nc',
#   'italy_s1asc_3362_enriched.nc',
#   'italy_s1asc_3345_enriched.nc',
#   'italy_s1asc_2540_enriched.nc',
#   'italy_s1asc_2551_enriched.nc',
#   'italy_s1asc_2845_enriched.nc',
#   'italy_s1asc_2607_enriched.nc',
#   'italy_s1asc_3311_enriched.nc',
#   'italy_s1asc_3557_enriched.nc',
#   'italy_s1asc_3674_enriched.nc',
#   'italy_s1asc_2781_enriched.nc',
#   'italy_s1asc_2994_enriched.nc',
#   'italy_s1asc_2786_enriched.nc',
#   'italy_s1asc_252_enriched.nc',
#   'italy_s1asc_3527_enriched.nc',
#   'italy_s1asc_2888_enriched.nc',
#   'italy_s1asc_2999_enriched.nc',
#   'italy_s1asc_3714_enriched.nc',
#   'italy_s1asc_3397_enriched.nc',
#   'italy_s1asc_330_enriched.nc',
#   'italy_s1asc_3314_enriched.nc',
#   'italy_s1asc_3194_enriched.nc',
#   'italy_s1asc_3638_enriched.nc',
#   'italy_s1asc_3704_enriched.nc',
#   'italy_s1asc_2698_enriched.nc',
#   'italy_s1asc_2788_enriched.nc',
#   'italy_s1asc_2802_enriched.nc',
#   'italy_s1asc_3305_enriched.nc',
#   'italy_s1asc_3614_enriched.nc',
#   'italy_s1asc_3178_enriched.nc',
#   'italy_s1asc_2790_enriched.nc',
#   'italy_s1asc_2968_enriched.nc']}

# %%
# Vemos si tenemos GPU disponible ...
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    print("Usando dispositivo: CUDA 🚀")
else:
    print("Usando dispositivo: CPU 😞")

# Dataset que vamos a utilizar.
DATASET= "dataset_conversational.txt"
# Out:
# Usando dispositivo: CUDA 🚀

# %%
class LandslideDataset(Dataset):
    def __init__(self, patches_dir, patch_ids, dynamic_vars, static_vars, mean=None, std=None):
        self.patches_dir = patches_dir
        self.patch_ids = patch_ids
        self.dynamic_vars = dynamic_vars
        self.static_vars = static_vars
        self.mean = mean
        self.std = std
    def __len__(self):
        return len(self.patch_ids)

    def __getitem__(self, idx):
        patch_id = self.patch_ids[idx]
        path = os.path.join(self.patches_dir, patch_id)

        ds = xr.open_dataset(path)

        # ---------- DINÁMICAS ----------
        dyn_list = []
        for var in self.dynamic_vars:
            arr = ds[var].values.astype(np.float32)  # (time, H, W)
            dyn_list.append(arr)

        # ---------- ESTÁTICAS ----------
        static_list = []
        for var in self.static_vars:
            arr = ds[var].values.astype(np.float32)

            if "time" in ds[var].dims:
                arr = arr[0]  # quitar dimensión time

            # repetir en el tiempo
            time_len = dyn_list[0].shape[0]
            arr = np.repeat(arr[None, :, :], time_len, axis=0)

            static_list.append(arr)

        # ---------- COMBINAR ----------
        all_vars = dyn_list + static_list  # lista de (time, H, W)

        # (channels, time, H, W)
        x = np.stack(all_vars, axis=0)

        # ---------- MASK ----------
        mask = ds["MASK"].values

        if "time" in ds["MASK"].dims:
            mask = mask[0]

        y = mask.astype(np.int64)  # para CrossEntropy

        ds.close()

        # convertir a tensor
        x = torch.from_numpy(x)  # float32
        y = torch.from_numpy(y)

        # ---------- NORMALIZACIÓN ----------
        if self.mean is not None and self.std is not None:
            x = (x - self.mean[:, None, None, None]) / (self.std[:, None, None, None] + 1e-6)

        return x, y

# %%
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
print(torch.backends.cudnn.enabled)
# Out:
# 2.7.1+cu118
# True
# 11.8
# True

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# 1
# NVIDIA GeForce RTX 2060

# %%
# Obtenemos los ids de los patches para el split de entrenamiento que están en el archivo split.json
output_path = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split.json"
with open(output_path, "r", encoding="utf-8") as f:
    split = json.load(f)
patches_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files\asc"
dynamic_vars = ["VV","VH", "prec7", "prec20", "max2d_7"]
static_vars = ["DEM", "slope", "aspect_sin", "aspect_cos", "profile_curvature", "area_drainage", "ls", "spi", "twi", "distance_to_drainage", "lithology_class"]


train_dataset = LandslideDataset(
    patches_dir,
    split["train"],
    dynamic_vars,
    static_vars
)

x, y = train_dataset[0]

print(x.shape)  # esperado: (channels, time, 128, 128)
print(y.shape)  # esperado: (128, 128)
# Out:
# torch.Size([16, 8, 128, 128])
# torch.Size([128, 128])

# %%
x, y = train_dataset[0]

print(x.mean(), x.std())
# Out:
# tensor(721.9541) tensor(14121.8320)

# %% [markdown]
# Hay que aplicar normalización

# %%
def compute_mean_std(dataset, max_samples=None):
    """
    Calcula mean y std por canal usando solo TRAIN
    """
    sum_ = None
    sum_sq = None
    n_pixels = 0

    n = len(dataset)
    if max_samples:
        n = min(n, max_samples)

    for i in tqdm(range(n)):
        x, _ = dataset[i]  # (C, T, H, W)

        x = x.view(x.shape[0], -1)  # (C, T*H*W)

        if sum_ is None:
            sum_ = x.sum(dim=1)
            sum_sq = (x ** 2).sum(dim=1)
        else:
            sum_ += x.sum(dim=1)
            sum_sq += (x ** 2).sum(dim=1)

        n_pixels += x.shape[1]

    mean = sum_ / n_pixels
    std = torch.sqrt(sum_sq / n_pixels - mean ** 2)

    return mean, std

# %%
mean, std = compute_mean_std(train_dataset, max_samples=100)

print(mean.shape)  # (C,)
print(std.shape)
# Out:
#  23%|██▎       | 23/100 [01:13<04:07,  3.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mean, std = compute_mean_std(train_dataset, max_samples=100)
#       2
#       3 print(mean.shape)  # (C,)
#       4 print(std.shape)
#
# Cell In[6], line 14, in compute_mean_std(dataset, max_samples)
#      10     if max_samples:
#      11         n = min(n, max_samples)
#      12
#      13     for i in tqdm(range(n)):
# ---> 14         x, _ = dataset[i]  # (C, T, H, W)
#      15
#      16         x = x.view(x.shape[0], -1)  # (C, T*H*W)
#      17
#
# Cell In[2], line 16, in LandslideDataset.__getitem__(self, idx)
#      12     def __getitem__(self, idx):
#      13         patch_id = self.patch_ids[idx]
#      14         path = os.path.join(self.patches_dir, patch_id)
#      15
# ---> 16         ds = xr.open_dataset(path)
#      17
#      18         # ---------- DINÁMICAS ----------
#      19         dyn_list = []
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\api.py:607, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     595 decoders = _resolve_decoders_kwargs(
#     596     decode_cf,
#     597     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    603     decode_coords=decode_coords,
#     604 )
#     606 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 607 backend_ds = backend.open_dataset(
#     608     filename_or_obj,
#     609     drop_variables=drop_variables,
#     610     **decoders,
#     611     **kwargs,
#     612 )
#     613 ds = _dataset_from_backend_dataset(
#     614     backend_ds,
#     615     filename_or_obj,
#    (...)    626     **kwargs,
#     627 )
#     628 return ds
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:786, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     784 store_entrypoint = StoreBackendEntrypoint()
#     785 with close_on_error(store):
# --> 786     ds = store_entrypoint.open_dataset(
#     787         store,
#     788         mask_and_scale=mask_and_scale,
#     789         decode_times=decode_times,
#     790         concat_characters=concat_characters,
#     791         decode_coords=decode_coords,
#     792         drop_variables=drop_variables,
#     793         use_cftime=use_cftime,
#     794         decode_timedelta=decode_timedelta,
#     795     )
#     796 return ds
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\store.py:42, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, set_indexes, use_cftime, decode_timedelta)
#      27 def open_dataset(
#      28     self,
#      29     filename_or_obj: T_PathFileOrDataStore,
#    (...)     38     decode_timedelta=None,
#      39 ) -> Dataset:
#      40     assert isinstance(filename_or_obj, AbstractDataStore)
# ---> 42     vars, attrs = filename_or_obj.load()
#      43     encoding = filename_or_obj.get_encoding()
#      45     vars, attrs, coord_names = conventions.decode_cf_variables(
#      46         vars,
#      47         attrs,
#    (...)     54         decode_timedelta=decode_timedelta,
#      55     )
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\common.py:366, in AbstractDataStore.load(self)
#     347 def load(self):
#     348     """
#     349     This loads the variables and attributes simultaneously.
#     350     A centralized loading function makes it easier to create
#    (...)    363     are requested, so care should be taken to make sure its fast.
#     364     """
#     365     variables = FrozenDict(
# --> 366         (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     367     )
#     368     attributes = FrozenDict(self.get_attrs())
#     369     return variables, attributes
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:584, in NetCDF4DataStore.get_variables(self)
#     583 def get_variables(self):
# --> 584     return FrozenDict(
#     585         (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     586     )
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\core\utils.py:522, in FrozenDict(*args, **kwargs)
#     521 def FrozenDict(*args, **kwargs) -> Frozen:
# --> 522     return Frozen(dict(*args, **kwargs))
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:585, in <genexpr>(.0)
#     583 def get_variables(self):
#     584     return FrozenDict(
# --> 585         (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     586     )
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:559, in NetCDF4DataStore.open_store_variable(self, name, var)
#     557 _ensure_fill_value_valid(data, attributes)
#     558 # netCDF4 specific encoding; save _FillValue for later
# --> 559 filters = var.filters()
#     560 if filters is not None:
#     561     encoding.update(filters)
#
# KeyboardInterrupt:

# %% [markdown]
# Redefinimos train dataset con la normalización en la clase LandslideDataset

# %%
# Obtenemos los ids de los patches para el split de entrenamiento que están en el archivo split.json
output_path = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split.json"
with open(output_path, "r", encoding="utf-8") as f:
    split = json.load(f)
patches_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files\asc"
dynamic_vars = ["VV","VH", "prec7", "prec20", "max2d_7"]
static_vars = ["DEM", "slope", "aspect_sin", "aspect_cos", "profile_curvature", "area_drainage", "ls", "spi", "twi", "distance_to_drainage", "lithology_class"]


train_dataset_raw = LandslideDataset(
    patches_dir,
    split["train"],
    dynamic_vars,
    static_vars
)

# %%
mean, std = compute_mean_std(train_dataset_raw, max_samples=100)
# Out:
# 100%|██████████| 100/100 [04:27<00:00,  2.68s/it]

# %%
print(mean)
# Out:
# tensor([-8.9904e+00, -1.5245e+01,  3.9258e+02,  7.4544e+02,  3.1974e+02,
#          5.8875e-03,  3.8816e+02,  1.5651e+01, -3.6811e-02,  1.2341e-01,
#         -1.0071e-04,  8.7210e+04,  1.0095e+01,  2.4936e+04,  9.0327e+00,
#          1.8893e+02,  8.1041e+00])

# %%
train_dataset = LandslideDataset(
    patches_dir,
    split["train"],
    dynamic_vars,
    static_vars, mean=mean, std=std
)

val_dataset = LandslideDataset(
    patches_dir=patches_dir,
    patch_ids=split["val"],
    dynamic_vars=dynamic_vars,
    static_vars=static_vars,
    mean=mean,
    std=std
)

test_dataset = LandslideDataset(
    patches_dir=patches_dir,
    patch_ids=split["test"],
    dynamic_vars=dynamic_vars,
    static_vars=static_vars,
    mean=mean,
    std=std
)

# %%
x, y = train_dataset[0]  # ← dataset CON normalización

print(x.mean(), x.std())
# Out:
# tensor(0.0817) tensor(0.9364)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=1,
    shuffle=True,
    num_workers=0,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %%
x, y = next(iter(train_loader))

print(x.shape)  # (B, C, T, H, W)
print(y.shape)
# Out:
# torch.Size([1, 17, 8, 128, 128])
# torch.Size([1, 128, 128])

# %% [markdown]
# Modelo 3D-UNET sencillo

# %%
class DoubleConv3D(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)


class Simple3DUNet(nn.Module):
    def __init__(self, in_channels, num_classes=2):
        super().__init__()

        self.enc1 = DoubleConv3D(in_channels, 16)
        self.pool1 = nn.MaxPool3d((1, 2, 2))

        self.enc2 = DoubleConv3D(16, 32)
        self.pool2 = nn.MaxPool3d((1, 2, 2))

        self.bottleneck = DoubleConv3D(32, 64)

        self.up2 = nn.ConvTranspose3d(64, 32, kernel_size=(1, 2, 2), stride=(1, 2, 2))
        self.dec2 = DoubleConv3D(64, 32)

        self.up1 = nn.ConvTranspose3d(32, 16, kernel_size=(1, 2, 2), stride=(1, 2, 2))
        self.dec1 = DoubleConv3D(32, 16)

        self.out = nn.Conv3d(16, num_classes, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        p1 = self.pool1(e1)

        e2 = self.enc2(p1)
        p2 = self.pool2(e2)

        b = self.bottleneck(p2)

        u2 = self.up2(b)
        d2 = self.dec2(torch.cat([u2, e2], dim=1))

        u1 = self.up1(d2)
        d1 = self.dec1(torch.cat([u1, e1], dim=1))

        out = self.out(d1)          # (B, 2, T, H, W)
        out = out.mean(dim=2)       # (B, 2, H, W)

        return out

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Simple3DUNet(
    in_channels=17,
    num_classes=2
).to(device)

print(device)
# Out:
# cuda

# %% [markdown]
# Function loss y optimzador

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# Training loop mínimo. Entrenamos y validamos por cada época.

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0

    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        optimizer.zero_grad()

        logits = model(x)          # (B, 2, H, W)
        loss = criterion(logits, y)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(loader)


def validate_one_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0

    with torch.no_grad():
        for x, y in loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            logits = model(x)
            loss = criterion(logits, y)

            total_loss += loss.item()

    return total_loss / len(loader)

# %% [markdown]
# Entrenamiento

# %%
num_epochs = 5

for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
    val_loss = validate_one_epoch(model, val_loader, criterion, device)

    print(
        f"Epoch {epoch+1}/{num_epochs} | "
        f"Train loss: {train_loss:.4f} | "
        f"Val loss: {val_loss:.4f}"
    )
# Out:
# Epoch 1/5 | Train loss: 0.3905 | Val loss: 0.2737
# Epoch 2/5 | Train loss: 0.2042 | Val loss: 0.1515
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 4
#       1 num_epochs = 5
#       2
#       3 for epoch in range(num_epochs):
# ----> 4     train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
#       5     val_loss = validate_one_epoch(model, val_loader, criterion, device)
#       6
#       7     print(
#
# Cell In[21], line 5, in train_one_epoch(model, loader, criterion, optimizer, device)
#       1 def train_one_epoch(model, loader, criterion, optimizer, device):
#       2     model.train()
#       3     total_loss = 0.0
#       4
# ----> 5     for x, y in loader:
#       6         x = x.to(device, non_blocking=True)
#       7         y = y.to(device, non_blocking=True)
#       8
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[4], line 16, in LandslideDataset.__getitem__(self, idx)
#      12     def __getitem__(self, idx):
#      13         patch_id = self.patch_ids[idx]
#      14         path = os.path.join(self.patches_dir, patch_id)
#      15
# ---> 16         ds = xr.open_dataset(path)
#      17
#      18         # ---------- DINÁMICAS ----------
#      19         dyn_list = []
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\api.py:607, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     595 decoders = _resolve_decoders_kwargs(
#     596     decode_cf,
#     597     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)    603     decode_coords=decode_coords,
#     604 )
#     606 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 607 backend_ds = backend.open_dataset(
#     608     filename_or_obj,
#     609     drop_variables=drop_variables,
#     610     **decoders,
#     611     **kwargs,
#     612 )
#     613 ds = _dataset_from_backend_dataset(
#     614     backend_ds,
#     615     filename_or_obj,
#    (...)    626     **kwargs,
#     627 )
#     628 return ds
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:786, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     784 store_entrypoint = StoreBackendEntrypoint()
#     785 with close_on_error(store):
# --> 786     ds = store_entrypoint.open_dataset(
#     787         store,
#     788         mask_and_scale=mask_and_scale,
#     789         decode_times=decode_times,
#     790         concat_characters=concat_characters,
#     791         decode_coords=decode_coords,
#     792         drop_variables=drop_variables,
#     793         use_cftime=use_cftime,
#     794         decode_timedelta=decode_timedelta,
#     795     )
#     796 return ds
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\store.py:42, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, set_indexes, use_cftime, decode_timedelta)
#      27 def open_dataset(
#      28     self,
#      29     filename_or_obj: T_PathFileOrDataStore,
#    (...)     38     decode_timedelta=None,
#      39 ) -> Dataset:
#      40     assert isinstance(filename_or_obj, AbstractDataStore)
# ---> 42     vars, attrs = filename_or_obj.load()
#      43     encoding = filename_or_obj.get_encoding()
#      45     vars, attrs, coord_names = conventions.decode_cf_variables(
#      46         vars,
#      47         attrs,
#    (...)     54         decode_timedelta=decode_timedelta,
#      55     )
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\common.py:366, in AbstractDataStore.load(self)
#     347 def load(self):
#     348     """
#     349     This loads the variables and attributes simultaneously.
#     350     A centralized loading function makes it easier to create
#    (...)    363     are requested, so care should be taken to make sure its fast.
#     364     """
#     365     variables = FrozenDict(
# --> 366         (_decode_variable_name(k), v) for k, v in self.get_variables().items()
#     367     )
#     368     attributes = FrozenDict(self.get_attrs())
#     369     return variables, attributes
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:584, in NetCDF4DataStore.get_variables(self)
#     583 def get_variables(self):
# --> 584     return FrozenDict(
#     585         (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     586     )
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\core\utils.py:522, in FrozenDict(*args, **kwargs)
#     521 def FrozenDict(*args, **kwargs) -> Frozen:
# --> 522     return Frozen(dict(*args, **kwargs))
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:585, in <genexpr>(.0)
#     583 def get_variables(self):
#     584     return FrozenDict(
# --> 585         (k, self.open_store_variable(k, v)) for k, v in self.ds.variables.items()
#     586     )
#
# File c:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\TFG\Lib\site-packages\xarray\backends\netCDF4_.py:559, in NetCDF4DataStore.open_store_variable(self, name, var)
#     557 _ensure_fill_value_valid(data, attributes)
#     558 # netCDF4 specific encoding; save _FillValue for later
# --> 559 filters = var.filters()
#     560 if filters is not None:
#     561     encoding.update(filters)
#
# KeyboardInterrupt:

# %%
t0 = time.time()
x, y = train_dataset[0]
print("Tiempo dataset[0]:", time.time() - t0)

t0 = time.time()
x, y = next(iter(train_loader))
print("Tiempo primer batch:", time.time() - t0)
# Out:
# Tiempo dataset[0]: 2.477560043334961
# Tiempo primer batch: 2.4441237449645996

# %% [markdown]
# El tiempo es exagerado así que hay que convertir los nc a pt. Para ello, partimos del training dataset raw.

# %%
x = x.float()   # asegúrate de float32
y = y.long()
print(x.dtype, y.dtype)
# Out:
# torch.float32 torch.int64

# %% [markdown]
# torch.save(train_dataset_raw

# %%
output_path = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_Sen2.json"

with open(output_path, "r", encoding="utf-8") as f:
    split = json.load(f)
dynamic_vars = ["B05","B06", "B07", "B11", "B12", "NDVI", "NBR", "prec7", "prec20", "max2d_7"]
static_vars = ["DEM", "slope", "aspect_sin", "aspect_cos", "profile_curvature", "area_drainage", "ls", "spi", "twi", "distance_to_drainage", "lithology_class"]

# %%
all_patch_ids = split["train"] + split["val"] + split["test"]
patches_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files\Sen2"
raw_dataset_all = LandslideDataset(
    patches_dir=patches_dir,
    patch_ids=all_patch_ids,
    dynamic_vars=dynamic_vars,
    static_vars=static_vars
)
pt_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files_pt\Sen2"
for i, patch_id in tqdm(enumerate(all_patch_ids), total=len(all_patch_ids)):
    x, y = raw_dataset_all[i]

    out_path = os.path.join(pt_dir, patch_id.replace(".nc", ".pt"))

    torch.save({
        "x": x,
        "y": y,
        "patch_id": patch_id
    }, out_path)
# Out:
# 100%|██████████| 835/835 [52:33<00:00,  3.78s/it]

# %%
class LandslideTensorDataset(Dataset):
    def __init__(self, pt_dir, patch_ids, mean=None, std=None):
        self.pt_dir = pt_dir
        self.patch_ids = patch_ids
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.patch_ids)

    def __getitem__(self, idx):
        patch_id = self.patch_ids[idx]
        path = os.path.join(self.pt_dir, patch_id.replace(".nc", ".pt"))

        item = torch.load(path, map_location="cpu")

        x = item["x"].float()
        y = item["y"].long()

        if self.mean is not None and self.std is not None:
            x = (x - self.mean[:, None, None, None]) / (self.std[:, None, None, None] + 1e-6)

        return x, y

# %% [markdown]
# train_dataset_tensor = LandslidetensorDataset(pt_dir sin mean, ni std

# %%
pt_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files_pt\asc"
output_path = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split.json"
with open(output_path, "r", encoding="utf-8") as f:
    split = json.load(f)
train_dataset_raw = LandslideTensorDataset(
    pt_dir=pt_dir,
    patch_ids=split["train"]
)

# %% [markdown]
# compute_mean_std(train_dataset_tensor

# %%
mean, std = compute_mean_std(train_dataset_raw)
# Out:
# 100%|██████████| 668/668 [00:12<00:00, 53.36it/s]

# %% [markdown]
# LandslidetensorDataset(pt_dir  con mean y std

# %%
train_dataset = LandslideTensorDataset(
    pt_dir=pt_dir,
    patch_ids=split["train"],
    mean=mean,
    std=std
)

val_dataset = LandslideTensorDataset(
    pt_dir=pt_dir,
    patch_ids=split["val"],
    mean=mean,
    std=std
)

test_dataset = LandslideTensorDataset(
    pt_dir=pt_dir,
    patch_ids=split["test"],
    mean=mean,
    std=std
)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=1,
    shuffle=True,
    num_workers=0,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %% [markdown]
# osea el flujo en realidad ha sido. train_dataset_raw = landslideDataset(  --> torch.save(train_dataset_raw  --> train_dataset_tensor = LandslidetensorDataset(pt_dir sin mean, ni std --> compute_mean_std(train_dataset_tensor --> LandslidetensorDataset(pt_dir  con mean y std

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Simple3DUNet(
    in_channels=16,
    num_classes=2
).to(device)

# 4. Loss y optimizador
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# 5. Entrenamiento

# %%
best_val_loss = float("inf")
num_epochs = 10
dynamic_vars = ["VV","VH", "prec7", "prec20", "max2d_7"]
static_vars = ["DEM", "slope", "aspect_sin", "aspect_cos", "profile_curvature", "area_drainage", "ls", "spi", "twi", "distance_to_drainage", "lithology_class"]
for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer, device)
    val_loss = validate_one_epoch(model, val_loader, criterion, device)

    print(
        f"Epoch {epoch+1}/{num_epochs} | "
        f"Train loss: {train_loss:.4f} | "
        f"Val loss: {val_loss:.4f}"
    )

    if val_loss < best_val_loss:
        best_val_loss = val_loss

        torch.save({
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "val_loss": val_loss,
            "mean": mean,
            "std": std,
            "config": {
                "in_channels": 17,
                "num_classes": 2,
                "dynamic_vars": dynamic_vars,
                "static_vars": static_vars
            }
        }, "best_model_sen2_3dunet.pth")

        print("✅ Nuevo mejor modelo guardado")
# Out:
# Epoch 1/10 | Train loss: 0.0402 | Val loss: 0.0355
# ✅ Nuevo mejor modelo guardado
# Epoch 2/10 | Train loss: 0.0371 | Val loss: 0.0312
# ✅ Nuevo mejor modelo guardado
# Epoch 3/10 | Train loss: 0.0352 | Val loss: 0.0332
# Epoch 4/10 | Train loss: 0.0339 | Val loss: 0.0316
# Epoch 5/10 | Train loss: 0.0331 | Val loss: 0.0287
# ✅ Nuevo mejor modelo guardado
# Epoch 6/10 | Train loss: 0.0321 | Val loss: 0.0316
# Epoch 7/10 | Train loss: 0.0316 | Val loss: 0.0291
# Epoch 8/10 | Train loss: 0.0310 | Val loss: 0.0291
# Epoch 9/10 | Train loss: 0.0306 | Val loss: 0.0281
# ✅ Nuevo mejor modelo guardado
# Epoch 10/10 | Train loss: 0.0299 | Val loss: 0.0300

# %% [markdown]
# Mapa de riesgo

# %%
checkpoint = torch.load("best_model_sen2_3dunet.pth", map_location=device)

model.load_state_dict(checkpoint["model_state_dict"])
model.to(device)

model.eval()
# Out:
# Simple3DUNet(
#   (enc1): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (pool1): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (enc2): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (pool2): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (up2): ConvTranspose3d(64, 32, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#   (dec2): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (up1): ConvTranspose3d(32, 16, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#   (dec1): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (out): Conv3d(16, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %% [markdown]
# Proceso completo para visualizar sin volver a entrenar

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Simple3DUNet(
    in_channels=16,
    num_classes=2
)
checkpoint = torch.load("best_model_sen2_3dunet.pth", map_location=device)

model.load_state_dict(checkpoint["model_state_dict"])
model.to(device)
model.eval()
# Out:
# Simple3DUNet(
#   (enc1): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (pool1): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (enc2): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (pool2): MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (up2): ConvTranspose3d(64, 32, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#   (dec2): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (up1): ConvTranspose3d(32, 16, kernel_size=(1, 2, 2), stride=(1, 2, 2))
#   (dec1): DoubleConv3D(
#     (block): Sequential(
#       (0): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (1): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       (4): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (out): Conv3d(16, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
mean = checkpoint["mean"].cpu()
std = checkpoint["std"].cpu()
pt_dir = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Enriched_files_pt\asc"
output_path = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split.json"
with open(output_path, "r", encoding="utf-8") as f:
    split = json.load(f)
val_dataset = LandslideTensorDataset(
    pt_dir=pt_dir,
    patch_ids=split["val"],
    mean=mean,
    std=std
)

# %%
idx = random.randint(0, len(val_dataset)-1)

x, y = val_dataset[idx]
x = x.unsqueeze(0).to(device)

with torch.no_grad():
    logits = model(x)
    probs = torch.softmax(logits, dim=1)
    risk_map = probs[:, 1, :, :]

risk = risk_map[0].detach().cpu().numpy()
mask = y.detach().cpu().numpy()

print("Patch:", split["val"][idx])
print("Risk min/max:", risk.min(), risk.max())
print("MASK sum:", mask.sum())

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.imshow(risk, cmap="inferno")
plt.title("Mapa de riesgo")
plt.colorbar()

plt.subplot(1,2,2)
plt.imshow(mask, cmap="gray")
plt.title("MASK real")
plt.colorbar()

plt.tight_layout()
plt.show()
# Out:
# Patch: italy_s1asc_2874_enriched.nc
# Risk min/max: 0.0018509604 0.04900798
# MASK sum: 120

# %% [markdown]
# Vamos a replicar el json para s1dsc y sen2

# %%
def convert_patch_id(patch_id, new_prefix):
    """
    Convierte un patch_id a otro prefijo manteniendo el número.
    
    Ej:
    italy_s1asc_255_enriched.nc → italy_s1dsc_255_enriched.nc
    """
    base = os.path.basename(patch_id)

    parts = base.split("_")
    
    # parts = ['italy', 's1asc', '255', 'enriched.nc']
    if len(parts) < 4:
        raise ValueError(f"Formato inesperado: {patch_id}")
    
    new_name = f"{parts[0]}_{new_prefix}_{parts[2]}_{parts[3]}"
    
    return new_name


def convert_split_json(
    input_json,
    output_json,
    new_prefix,
    n_jobs=4
):
    """
    Replica un split.json cambiando el prefijo de los patch_ids.
    
    Parámetros:
    ----------
    input_json : str
        Ruta al json original (s1asc)
    output_json : str
        Ruta donde guardar el nuevo json
    new_prefix : str
        's1dsc' o 's2'
    n_jobs : int
        Número de procesos paralelos
    """

    with open(input_json, "r") as f:
        split = json.load(f)

    new_split = {}

    for key in ["train", "val", "test"]:
        patch_list = split[key]

        new_list = Parallel(n_jobs=n_jobs)(
            delayed(convert_patch_id)(pid, new_prefix)
            for pid in patch_list
        )

        new_split[key] = new_list

    # Guardar nuevo json
    with open(output_json, "w") as f:
        json.dump(new_split, f, indent=2)

    print(f"✅ Nuevo split guardado en: {output_json}")

# %%
input_json = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_asc.json"
output_json = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_dsc.json"

convert_split_json(
    input_json,
    output_json,
    new_prefix = "s1dsc",
    n_jobs=4
)
# Out:
# ✅ Nuevo split guardado en: C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_dsc.json

# %%
input_json = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_asc.json"
output_json = r"C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_Sen2.json"

convert_split_json(
    input_json,
    output_json,
    new_prefix = "s2",
    n_jobs=4
)
# Out:
# ✅ Nuevo split guardado en: C:\Users\gonra\Documents\NEW DEGREE YESSIR\4RTO CURSO\2NDOSEMESTRE\TFG\FREESTYLE_FOLDER\Procesamiento\split_Sen2.json

# %% [markdown]
# Guardar las predicciones

# %%
def save_predictions(
    model,
    dataset,
    split,
    device,
    output_dir
):
    """
    Guarda predicciones de un modelo para todos los patches de un dataset.
    """

    os.makedirs(output_dir, exist_ok=True)

    model.eval()

    for idx in tqdm(range(len(dataset))):

        patch_id = split[idx]

        x, y = dataset[idx]
        x = x.unsqueeze(0).to(device)

        with torch.no_grad():
            logits = model(x)
            probs = torch.softmax(logits, dim=1)
            risk_map = probs[:, 1, :, :]  # (1, H, W)

        risk_map = risk_map[0].cpu()  # (H, W)

        out_path = os.path.join(
            output_dir,
            patch_id.replace(".nc", "_pred.pt")
        )

        torch.save({
            "patch_id": patch_id,
            "prob": risk_map,
            "y": y  # opcional pero recomendable
        }, out_path)

    print(f"✅ Predicciones guardadas en: {output_dir}")

# %%
def extract_patch_id(filename):
    """
    Extrae el número de patch.
    Ej:
    italy_s1asc_255_pred.pt -> 255
    italy_s2_255_pred.pt    -> 255
    italy_fused_255_pred.pt -> 255
    """
    match = re.search(r"_(\d+)_", filename)
    if match is None:
        raise ValueError(f"No se pudo extraer ID de patch: {filename}")
    return match.group(1)


def build_index(pred_dir):
    """
    Crea índice {patch_id: filename}
    """
    files = [f for f in os.listdir(pred_dir) if f.endswith(".pt")]
    return {extract_patch_id(f): f for f in files}


def load_prob_item(path):
    """
    Carga una predicción.
    Acepta archivos con clave 'prob' o 'prob_final'.
    """
    item = torch.load(path, map_location="cpu")

    if "prob_final" in item:
        prob = item["prob_final"].float()
    elif "prob" in item:
        prob = item["prob"].float()
    else:
        raise KeyError(f"No existe 'prob' ni 'prob_final' en {path}")

    y = item.get("y", None)
    if y is not None:
        y = y.long()

    patch_id = item.get("patch_id", None)

    return prob, y, patch_id


def get_predictions(
    pred_dirs,
    weights=None,
    output_dir=None,
    threshold=0.5,
    return_metrics=True
):
    """
    Función general para predicciones individuales o fusionadas.

    Parámetros
    ----------
    pred_dirs : str o list[str]
        Una carpeta para un modelo solo, o varias carpetas para fusión.
        Ej:
        pred_dirs="/content/pred_s2_val"
        pred_dirs=["/content/pred_s1asc_val", "/content/pred_s1dsc_val"]

    weights : list[float] o None
        Pesos de fusión. Si None, media simple.

    output_dir : str o None
        Si se indica, guarda las predicciones fusionadas/normalizadas.

    threshold : float
        Umbral para convertir probabilidad en máscara binaria.

    return_metrics : bool
        Si True, calcula métricas si existe y.

    Devuelve
    --------
    results : dict
        {
            patch_id: {
                "prob_final": tensor(H,W),
                "y": tensor(H,W) or None,
                "pred": tensor(H,W)
            }
        }

    metrics : dict o None
    """

    if isinstance(pred_dirs, str):
        pred_dirs = [pred_dirs]

    n_models = len(pred_dirs)

    if weights is None:
        weights = [1.0 / n_models] * n_models
    else:
        assert len(weights) == n_models, "weights debe tener la misma longitud que pred_dirs"
        s = sum(weights)
        weights = [w / s for w in weights]

    if output_dir is not None:
        os.makedirs(output_dir, exist_ok=True)

    indices = [build_index(d) for d in pred_dirs]

    common_ids = set(indices[0].keys())
    for idx in indices[1:]:
        common_ids &= set(idx.keys())

    common_ids = sorted(common_ids, key=lambda x: int(x))

    results = {}

    tp = fp = fn = tn = 0

    for patch_num in tqdm(common_ids):

        probs = []
        y_ref = None

        for d, index, w in zip(pred_dirs, indices, weights):
            file = index[patch_num]
            path = os.path.join(d, file)

            prob, y, patch_id = load_prob_item(path)
            probs.append(w * prob)

            if y_ref is None and y is not None:
                y_ref = y

        prob_final = torch.stack(probs, dim=0).sum(dim=0)
        pred = (prob_final >= threshold).long()

        results[patch_num] = {
            "prob_final": prob_final,
            "y": y_ref,
            "pred": pred
        }

        if output_dir is not None:
            out_path = os.path.join(output_dir, f"patch_{patch_num}_pred.pt")
            torch.save({
                "patch_id": patch_num,
                "prob_final": prob_final,
                "y": y_ref,
                "pred": pred,
                "weights": weights,
                "source_dirs": pred_dirs
            }, out_path)

        if return_metrics and y_ref is not None:
            y_ref = y_ref.long()

            tp += ((pred == 1) & (y_ref == 1)).sum().item()
            fp += ((pred == 1) & (y_ref == 0)).sum().item()
            fn += ((pred == 0) & (y_ref == 1)).sum().item()
            tn += ((pred == 0) & (y_ref == 0)).sum().item()

    metrics = None

    if return_metrics:
        eps = 1e-8

        precision = tp / (tp + fp + eps)
        recall = tp / (tp + fn + eps)
        f1 = 2 * precision * recall / (precision + recall + eps)
        iou = tp / (tp + fp + fn + eps)
        accuracy = (tp + tn) / (tp + tn + fp + fn + eps)

        metrics = {
            "threshold": threshold,
            "n_patches": len(common_ids),
            "TP": tp,
            "FP": fp,
            "FN": fn,
            "TN": tn,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "iou": iou,
            "accuracy": accuracy
        }

    return results, metrics

# %%
results_s2, metrics_s2 = get_predictions(
    pred_dirs="/content/drive/MyDrive/pred_sen2_val/pred_sen2_val",
    threshold=0.1
)

print(metrics_s2)
